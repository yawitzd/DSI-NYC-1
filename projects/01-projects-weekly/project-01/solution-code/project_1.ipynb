# %% [markdown]
# # Project 1
#
# ## Step 1: Open the `sat_scores.csv` file. Investigate the data, and answer the questions below.

# %% [markdown]
# ##### 1. What does the data describe?

# %% [markdown]
# SAT Math and Verbal scores, and participation rates, by state for the year 2001.
#
# The dataset includes data at the state level (as well as Washington D.C. and national statistics).

# %% [markdown]
# ##### 2. Does the data look complete? Are there any obvious issues with the observations?

# %% [markdown]
# Data looks good, no missing or erroneous observations.
#
# Nebraska is mistakenly described as "NB."

# %% [markdown]
# ## Step 2: Load the data.

# %% [markdown]
# ##### 3. Load the data into a list of lists

# %%
import csv

data= []
with open('../assets/sat_scores.csv', 'rU') as f:
    reader = csv.reader(f)
    for row in reader:
        data.append(row)
f.close()

# %% [markdown]
# ##### 4. Print the data

# %%
[row for row in data]
# Out:
# [['State', 'Rate', 'Verbal', 'Math'],
#  ['CT', '82', '509', '510'],
#  ['NJ', '81', '499', '513'],
#  ['MA', '79', '511', '515'],
#  ['NY', '77', '495', '505'],
#  ['NH', '72', '520', '516'],
#  ['RI', '71', '501', '499'],
#  ['PA', '71', '500', '499'],
#  ['VT', '69', '511', '506'],
#  ['ME', '69', '506', '500'],
#  ['VA', '68', '510', '501'],
#  ['DE', '67', '501', '499'],
#  ['MD', '65', '508', '510'],
#  ['NC', '65', '493', '499'],
#  ['GA', '63', '491', '489'],
#  ['IN', '60', '499', '501'],
#  ['SC', '57', '486', '488'],
#  ['DC', '56', '482', '474'],
#  ['OR', '55', '526', '526'],
#  ['FL', '54', '498', '499'],
#  ['WA', '53', '527', '527'],
#  ['TX', '53', '493', '499'],
#  ['HI', '52', '485', '515'],
#  ['AK', '51', '514', '510'],
#  ['CA', '51', '498', '517'],
#  ['AZ', '34', '523', '525'],
#  ['NV', '33', '509', '515'],
#  ['CO', '31', '539', '542'],
#  ['OH', '26', '534', '439'],
#  ['MT', '23', '539', '539'],
#  ['WV', '18', '527', '512'],
#  ['ID', '17', '543', '542'],
#  ['TN', '13', '562', '553'],
#  ['NM', '13', '551', '542'],
#  ['IL', '12', '576', '589'],
#  ['KY', '12', '550', '550'],
#  ['WY', '11', '547', '545'],
#  ['MI', '11', '561', '572'],
#  ['MN', '9', '580', '589'],
#  ['KS', '9', '577', '580'],
#  ['AL', '9', '559', '554'],
#  ['NB', '8', '562', '568'],
#  ['OK', '8', '567', '561'],
#  ['MO', '8', '577', '577'],
#  ['LA', '7', '564', '562'],
#  ['WI', '6', '584', '596'],
#  ['AR', '6', '562', '550'],
#  ['UT', '5', '575', '570'],
#  ['IA', '5', '593', '603'],
#  ['SD', '4', '577', '582'],
#  ['ND', '4', '592', '599'],
#  ['MS', '4', '566', '551'],
#  ['All', '45', '506', '514']]

# %% [markdown]
# ##### 5. Extract a list of the labels from the data, and remove them from the data.

# %%
labels = data[0]
data = data[1:]

# %% [markdown]
# ##### 6. Create a list of State names extracted from the data. (Hint: use the list of labels to index on the State column)

# %%
state_names = [row[labels.index('State')] for row in data[1:]]
print state_names
# Out:
# ['NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NB', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS', 'All']

# %% [markdown]
# ##### 7. Print the types of each column

# %%
[type(item) for item in data[0]]
# Out:
# [str, str, str, str]

# %%
#alternative:

# loop through the column labels and print the type for the data in each column
for i, name in enumerate(labels):
    print "For " + str(name) + " the data type is " + type(data[0][i]).__name__
# Out:
# For State the data type is str
# For Rate the data type is str
# For Verbal the data type is str
# For Math the data type is str

# %% [markdown]
# ##### 8. Do any types need to be reassigned? If so, go ahead and do it.

# %%
rate_i = labels.index('Rate')
math_i = labels.index('Math')
verbal_i = labels.index('Verbal')

for row in data:
    row[rate_i] = int(row[rate_i])
    row[math_i] = int(row[math_i])
    row[verbal_i] = int(row[verbal_i])
[type(item) for item in data[0]]
# Out:
# [str, int, int, int]

# %%
#alternative way:

#a list of data types
dType= [str, int, int, int]

#change each item in the list to the appropriate data type for each row of the data
data = [[t(x) for t,x in zip(dType,i)] for i in data]

# %% [markdown]
# ##### 9. Create a dictionary for each column mapping the State to its respective value for that column.

# %%
state_rate = {}
state_math = {}
state_verbal = {}

for row in data:
    state_rate[row[0]] = row[rate_i]
    state_math[row[0]] = row[math_i]
    state_verbal[row[0]] = row[verbal_i]

# %% [markdown]
# ##### 10. Create a dictionary with the values for each of the numeric columns

# %%
data_dict = {'rate': [row[labels.index('Rate')] for row in data],
             'math': [row[labels.index('Math')] for row in data],
             'verbal': [row[labels.index('Verbal')] for row in data]
            }

# %%
#dictionary comprehension:
data_dict = {column_name: [row[index] for row in data] for index, column_name in enumerate(labels)}

# %%
print data_dict
# Out:
# {'Math': [510, 513, 515, 505, 516, 499, 499, 506, 500, 501, 499, 510, 499, 489, 501, 488, 474, 526, 499, 527, 499, 515, 510, 517, 525, 515, 542, 439, 539, 512, 542, 553, 542, 589, 550, 545, 572, 589, 580, 554, 568, 561, 577, 562, 596, 550, 570, 603, 582, 599, 551, 514], 'State': ['CT', 'NJ', 'MA', 'NY', 'NH', 'RI', 'PA', 'VT', 'ME', 'VA', 'DE', 'MD', 'NC', 'GA', 'IN', 'SC', 'DC', 'OR', 'FL', 'WA', 'TX', 'HI', 'AK', 'CA', 'AZ', 'NV', 'CO', 'OH', 'MT', 'WV', 'ID', 'TN', 'NM', 'IL', 'KY', 'WY', 'MI', 'MN', 'KS', 'AL', 'NB', 'OK', 'MO', 'LA', 'WI', 'AR', 'UT', 'IA', 'SD', 'ND', 'MS', 'All'], 'Rate': [82, 81, 79, 77, 72, 71, 71, 69, 69, 68, 67, 65, 65, 63, 60, 57, 56, 55, 54, 53, 53, 52, 51, 51, 34, 33, 31, 26, 23, 18, 17, 13, 13, 12, 12, 11, 11, 9, 9, 9, 8, 8, 8, 7, 6, 6, 5, 5, 4, 4, 4, 45], 'Verbal': [509, 499, 511, 495, 520, 501, 500, 511, 506, 510, 501, 508, 493, 491, 499, 486, 482, 526, 498, 527, 493, 485, 514, 498, 523, 509, 539, 534, 539, 527, 543, 562, 551, 576, 550, 547, 561, 580, 577, 559, 562, 567, 577, 564, 584, 562, 575, 593, 577, 592, 566, 506]}

# %% [markdown]
# ## Step 3: Describe the data

# %% [markdown]
# ##### 11. Print the min and max of each column

# %%
print 'Rate: '
print ' - min: '  + str(min(data_dict['Rate']))
print ' - max: '  + str(max(data_dict['Rate']))

print 'Math: '
print ' - min: '  + str(min(data_dict['Math']))
print ' - max: '  + str(max(data_dict['Math']))

print 'Verbal: '
print ' - min: '  + str(min(data_dict['Verbal']))
print ' - max: '  + str(max(data_dict['Verbal']))
# Out:
# Rate:
#  - min: 4
#  - max: 82
# Math:
#  - min: 439
#  - max: 603
# Verbal:
#  - min: 482
#  - max: 593

# %% [markdown]
# ##### 12. Write a function using only list comprehensions, no loops, to compute Standard Deviation. Print the Standard Deviation of each numeric column.

# %%
from __future__ import division

def standard_deviation(values):
    mean = sum(values) / len(values)
    variances = [x - mean for x in values]
    squares = [y ** 2 for y in variances]
    variance_figure = sum(squares) / (len(values) - 1)
    sd = variance_figure ** 0.5
    return sd
    
print 'Rate:'
print standard_deviation(data_dict['Rate'])

print 'Math:'
print standard_deviation(data_dict['Math'])

print 'Verbal:'
print standard_deviation(data_dict['Verbal'])
# Out:
# Rate:
# 27.3017880729
# Math:
# 36.0149750989
# Verbal:
# 33.2362254438

# %% [markdown]
# ## Step 4: Visualize the data

# %% [markdown]
# ##### 13. Using MatPlotLib and PyPlot, plot the distribution of the Rate using histograms.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

n, bins, patches = plt.hist(data_dict['Rate'], 50, normed=1, facecolor='green', alpha=0.75)
# Out:
# /Users/dyawitz/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ##### 14. Plot the Math distribution

# %%
n, bins, patches = plt.hist(data_dict['Math'], 50, normed=1, facecolor='green', alpha=0.75)

# %% [markdown]
# ##### 15. Plot the Verbal distribution

# %%
n, bins, patches = plt.hist(data_dict['Verbal'], 50, normed=1, facecolor='green', alpha=0.75)

# %% [markdown]
# ##### 16. What is the typical assumption for data distribution?

# %%
plt.figure(figsize=(12,6))
sns.distplot(data_dict['Math'], bins = 20, color ='green')
sns.distplot(data_dict['Verbal'], bins = 20, color='red')

# %%
print 'We assume the distribution is normal'
# Out:
# We assume the distribution is normal

# %% [markdown]
# ##### 17. Does that distribution appear to hold true for our data?

# %%
print 'Nope. Math starts to look normal'
# Out:
# Nope. Math starts to look normal

# %% [markdown]
# ##### 18. Plot some scatterplots. **BONUS**: Use a PyPlot `figure` to present multiple plots at once.

# %%
fig = plt.figure()

ax1 = fig.add_subplot(131)
ax1.scatter(data_dict['Rate'], data_dict['Math'])
ax2 = fig.add_subplot(132)
ax2.scatter(data_dict['Rate'], data_dict['Verbal'])
ax3 = fig.add_subplot(133)
ax3.scatter(data_dict['Math'], data_dict['Verbal'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
plt.scatter(data_dict['Rate'], data_dict['Verbal'], c='r', marker = 'o', s=125, label='VERBAL')
plt.scatter(data_dict['Rate'], data_dict['Math'], c='k', marker = 'o', s=50, label='MATH')
plt.xlabel("student participation rate")
plt.ylabel("SAT scores")
plt.title('SAT scores by participation rate')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np

plt.figure(figsize=(12,6))
plt.style.use('fivethirtyeight')

df = pd.DataFrame(data_dict)

# make area of plot point proportional to testing rate of corresponding state
area = 3 * df['Rate']  

df_scatter = plt.scatter(df['Math'], df['Verbal'], s=area, alpha=0.5)

plt.title('Verbal vs Math SAT Score by State (without Ohio)', fontsize = 24)

# y label
plt.ylabel('Verbal Score')

# x label
plt.xlabel('Math Score')

# set the figure boundaries
plt.xlim([460, 610])
plt.ylim([460, 610])

df_m, df_b = np.polyfit(df['Math'], df['Verbal'], 1)

plt.plot(df['Math'], df_m*df['Math'] + df_b, '-', linewidth = 1.0)

# %%
plt.figure(figsize=(12,6))
sns.regplot(y="Math", x="Rate", data=df, color='darkgreen')
sns.regplot(y='Verbal', x='Rate', data=df, color='lightblue')
plt.show()

# %% [markdown]
# ##### 19. Are there any interesting relationships to note?

# %%
print 'Loose correlation between rate and math/verbal, strong correlation between math and verbal scores'
# Out:
# Loose correlation between rate and math/verbal, strong correlation between math and verbal scores

# %% [markdown]
# ##### 20. Create box plots for each variable.

# %%
fig = plt.figure()

ax1 = fig.add_subplot(131)
ax1.boxplot(data_dict['Rate'])
ax2 = fig.add_subplot(132)
ax2.boxplot(data_dict['Math'])
ax3 = fig.add_subplot(133)
ax3.boxplot(data_dict['Verbal'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x1190f3290>],
#  'caps': [<matplotlib.lines.Line2D at 0x1192061d0>,
#   <matplotlib.lines.Line2D at 0x119206810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1192124d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x119206e50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x1190f3490>,
#   <matplotlib.lines.Line2D at 0x1190f3b50>]}
