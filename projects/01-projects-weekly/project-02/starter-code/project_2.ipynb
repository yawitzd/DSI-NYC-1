# %% [markdown]
# # Project 2
# ## Step 1: Exploring your data.
#
# ##### Load your data in using Pandas and start to explore. Save all of your early exploration code here and include in your final submission.

# %%
# import packages
import re
import pandas as pd
import numpy as np
from datetime import datetime
import seaborn as sns
# %matplotlib inline


bb = pd.read_csv('/Users/Tamara/DSI-NYC-1/projects/01-projects-weekly/project-02/assets/billboard.csv')
bb.head()
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#   x2nd.week x3rd.week    ...     x67th.week x68th.week x69th.week x70th.week  \
# ...

# %% [markdown]
# ##### Write a brief description of your data, and any interesting observations you've made thus far.

# %% [markdown]
# The data above is a collection of songs released in 2000 which have managed to chart on the Billboard. A lot of the data is missing on the table and are in * to show that there is no value. The time is arranged in a weird fashion as it is impossible to know if the time is actually telling the time or if it's the actual length of the song. The fact that AM is added makes it more confusing. The genres are also mislabeled or not as labeling a genre a certain way is up to the person and maybe the billboards have their own way of classifying songs and also the genres were (I think) according to the song and not to the type of singer the artist is. I decided The dates are also printed incorrectly and are not in the day-month-year order.

# %% [markdown]
# ## Step 2: Clean your data.

# %% [markdown]
# ##### Do some rudimentary cleaning. Rename any columns that are poorly named, shorten any strings that may be too long, fill in any missing values. Explain your rationale for the way you choose to "impute" the missing data.

# %%
bb.dtypes.head(20)
# Out:
# year                int64
# artist.inverted    object
# track              object
# time               object
# genre              object
# date.entered       object
# date.peaked        object
# x1st.week           int64
# x2nd.week          object
# x3rd.week          object
# x4th.week          object
# x5th.week          object
# x6th.week          object
# x7th.week          object
# x8th.week          object
# x9th.week          object
# x10th.week         object
# x11th.week         object
# x12th.week         object
# x13th.week         object
# dtype: object

# %%
bb.replace('*', np.nan, inplace=True)
bb.head()
# I chose to put a NaN in place of the *'s because there was a lot of missing data especially for the weeks beyond 
# week 3 that I did not think were needed as there was sufficient data available.
# Out:
#    year      artist.inverted                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date.entered         date.peaked  x1st.week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000         78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000         15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000         71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000         41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000         57
#
#   x2nd.week x3rd.week    ...     x67th.week x68th.week x69th.week x70th.week  \
# ...

# %%
new_cols = ['year', 'artist', 'track', 'time', 'genre', 'date_entered', 'date_peaked', '1st_week', '2nd_week', '3rd_week', '4th week', 'x5th.week', 'x6th.week', 'x7th.week', 'x8th.week', 'x9th.week', 'x10th.week', 'x11th.week', 'x12th.week', 'x13th.week', 'x14th.week', 'x15th.week', 'x16th.week', 'x17th.week', 'x18th.week', 'x19th.week', 'x20th.week', 'x21st.week', 'x22nd.week', 'x23rd.week', 'x24th.week', 'x25th.week', 'x26th.week', 'x27th.week', 'x28th.week', 'x29th.week', 'x30th.week', 'x31st.week', 'x32nd.week', 'x33rd.week', 'x34th.week', 'x35th.week', 'x36th.week', 'x37th.week', 'x38th.week', 'x39th.week', 'x40th.week', 'x41st.week', 'x42nd.week', 'x43rd.week', 'x44th.week', 'x45th.week', 'x46th.week', 'x47th.week', 'x48th.week', 'x49th.week', 'x50th.week', 'x51st.week', 'x52nd.week', 'x53rd.week', 'x54th.week', 'x55th.week', 'x56th.week', 'x57th.week', 'x58th.week', 'x59th.week', 'x60th.week', 'x61st.week', 'x62nd.week', 'x63rd.week', 'x64th.week', 'x65th.week', 'x66th.week', 'x67th.week', 'x68th.week', 'x69th.week', 'x70th.week', 'x71st.week', 'x72nd.week', 'x73rd.week', 'x74th.week', 'x75th.week', 'x76th.week']
bb.columns = new_cols

# %%
bb.head(5)
# Out:
#    year               artist                                  track  \
# 0  2000      Destiny's Child               Independent Women Part I
# 1  2000              Santana                           Maria, Maria
# 2  2000        Savage Garden                     I Knew I Loved You
# 3  2000              Madonna                                  Music
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)
#
#          time genre        date_entered         date_peaked  1st_week  \
# 0  3,38,00 AM  Rock  September 23, 2000   November 18, 2000        78
# 1  4,18,00 AM  Rock   February 12, 2000       April 8, 2000        15
# 2  4,07,00 AM  Rock    October 23, 1999    January 29, 2000        71
# 3  3,45,00 AM  Rock     August 12, 2000  September 16, 2000        41
# 4  3,38,00 AM  Rock      August 5, 2000    October 14, 2000        57
#
#   2nd_week 3rd_week    ...     x67th.week x68th.week x69th.week x70th.week  \
# ...

# %%
bb.tail(5)
# Out:
#      year            artist             track        time  genre  \
# 312  2000  Ghostface Killah  Cherchez LaGhost  3,04,00 AM  R & B
# 313  2000       Smith, Will       Freakin' It  3,58,00 AM    Rap
# 314  2000     Zombie Nation     Kernkraft 400  3,30,00 AM   Rock
# 315  2000    Eastsidaz, The          Got Beef  3,58,00 AM    Rap
# 316  2000            Fragma    Toca's Miracle  3,22,00 AM  R & B
#
#           date_entered        date_peaked  1st_week 2nd_week 3rd_week  \
# 312     August 5, 2000     August 5, 2000        98      NaN      NaN
# 313  February 12, 2000  February 12, 2000        99       99       99
# 314  September 2, 2000  September 2, 2000        99       99      NaN
# 315       July 1, 2000       July 1, 2000        99       99      NaN
# 316   October 28, 2000   October 28, 2000        99      NaN      NaN
#
#        ...     x67th.week x68th.week x69th.week x70th.week x71st.week  \
# 312    ...            NaN        NaN        NaN        NaN        NaN
# ...

# %%
#Check to see if there are any duplicate artists in the dataset
artists = pd.value_counts(bb['artist'])
artists = pd.DataFrame(artists)
print artists.head(20)
# Out:
#                       artist
# Jay-Z                      5
# Houston, Whitney           4
# Dixie Chicks, The          4
# DMX                        3
# Aguilera, Christina        3
# McGraw, Tim                3
# Backstreet Boys, The       3
# Thomas, Carl               3
# N'Sync                     3
# Destiny's Child            3
# SheDaisy                   3
# Sisqo                      3
# Braxton, Toni              3
# Limp Bizkit                3
# Price, Kelly               3
# Spears, Britney            3
# Rimes, LeAnn               3
# Eminem                     3
# Lonestar                   3
# Martin, Ricky              3

# %%
#check for duplicate tracks
pd.value_counts(bb['track'])
# Out:
# Where I Wanna Be                       2
# If You Don't Wanna Love Me             1
# Just Be A Man About It                 1
# With Arms Wide Open                    1
# Girls Dem Sugar                        1
# More                                   1
# Rhythm Divine                          1
# Case Of The Ex (Whatcha Gonna Do)      1
# Pull Over                              1
# Without You                            1
# We Danced                              1
# 911                                    1
# Left, Right, Left                      1
# N 2 Gether Now                         1
# I Lost It                              1
# Otherside                              1
# A Country Boy Can Survive              1
# Rollin'                                1
# Shackles (Praise You)                  1
# American Pie                           1
# I Think I'm In Love With You           1
# Feelin' Good                           1
# What You Want                          1
# ...

# %%
#check to see if track is by the same artist
bb[ bb['track'] == 'Where I Wanna Be' ]
# Out:
#      year         artist             track        time genre  \
# 118  2000  Jones, Donell  Where I Wanna Be  6,22,00 AM  Rock
# 305  2000  Sheist, Shade  Where I Wanna Be  4,16,00 AM   Rap
#
#           date_entered        date_peaked  1st_week 2nd_week 3rd_week  \
# 118     April 22, 2000       July 8, 2000        81       71       65
# 305  November 11, 2000  November 18, 2000        96       95       99
#
#        ...     x67th.week x68th.week x69th.week x70th.week x71st.week  \
# 118    ...            NaN        NaN        NaN        NaN        NaN
# 305    ...            NaN        NaN        NaN        NaN        NaN
#
#     x72nd.week x73rd.week x74th.week x75th.week x76th.week
# 118        NaN        NaN        NaN        NaN        NaN
# 305        NaN        NaN        NaN        NaN        NaN
#
# [2 rows x 83 columns]

# %%
#popular music
genres = pd.value_counts(bb['genre'])
genres = pd.DataFrame(genres)
genres
# Out:
#              genre
# Rock           103
# Country         74
# Rap             58
# Rock'n'roll     34
# R&B             13
# R & B           10
# Pop              9
# Latin            9
# Electronica      4
# Gospel           1
# Jazz             1
# Reggae           1

# %%
bb['artist'] = bb['artist'].apply(lambda x: re.sub(r'[^\x00-\x7f]',r'',x))
bb['track'] = bb['track'].apply(lambda x: re.sub(r'[^\x00-\x7f]',r'',x))
bb.head()
# Out:
#    year               artist                                  track  time  \
# 0  2000      Destiny's Child               Independent Women Part I   218
# 1  2000              Santana                           Maria, Maria   258
# 2  2000        Savage Garden                     I Knew I Loved You   247
# 3  2000              Madonna                                  Music   225
# 4  2000  Aguilera, Christina  Come On Over Baby (All I Want Is You)   218
#
#   genre date_entered date_peaked  1st_week 2nd_week 3rd_week    ...      \
# 0  Rock   2000-09-23  2000-11-18        78       63       49    ...
# 1  Rock   2000-02-12  2000-04-08        15        8        6    ...
# 2  Rock   1999-10-23  2000-01-29        71       48       43    ...
# 3  Rock   2000-08-12  2000-09-16        41       23       18    ...
# 4  Rock   2000-08-05  2000-10-14        57       47       45    ...
#
#   x67th.week x68th.week x69th.week x70th.week x71st.week x72nd.week  \
# ...

# %% [markdown]
# ##### Using Pandas' built in `melt` function, pivot the weekly ranking data to be long rather than wide. As a result, you will have removed the 72 'week' columns and replace it with two: Week and Ranking. There will now be multiple entries for each song, one for each week on the Billboard rankings.

# %%
bb_melted = pd.melt(bb, id_vars = ['Year', 'Artist','Track','Genre', 'Date_Entered', 'Date_Peaked'], var_name='Week', value_name = 'Ranking')

# %%
null_values = bb_melted['Ranking'].isnull()
null_values.value_counts()
# Out:
# True     18785
# False     5624
# Name: Ranking, dtype: int64

# %%
bb_clean = bb_melted.dropna(axis = 0)

# %%
top_track= bb_clean[bb_clean['Ranking']==1]
top_track_pivot = pd.pivot_table(top_track, index = 'Artist', values='Ranking', aggfunc=np.sum)

# %%
avg_rank_genre = pd.pivot_table(bb_melted, index=['Genre'], values= 'Ranking')
avg_rank_genre
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-13-7b7f6484953a> in <module>()
# ----> 1 avg_rank_genre = pd.pivot_table(bb_melted, index=['Genre'], values= 'Ranking')
#       2 avg_rank_genre
#
# /Users/Tamara/anaconda/lib/python2.7/site-packages/pandas/tools/pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     119
#     120     grouped = data.groupby(keys)
# --> 121     agged = grouped.agg(aggfunc)
#     122
#     123     table = agged
#
# /Users/Tamara/anaconda/lib/python2.7/site-packages/pandas/core/groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3595     @Appender(SelectionMixin._agg_doc)
#    3596     def aggregate(self, arg, *args, **kwargs):
# -> 3597         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3598
#    3599     agg = aggregate
#
# ...

# %% [markdown]
# ## Step 3: Visualize your data.

# %% [markdown]
# ##### Using a plotting utility of your choice (Tableau or python modules or both), create visualizations that will provide context to your data. There is no minimum or maximum number of graphs you should generate, but there should be a clear and consistent story being told. Give insights to the distribution, statistics, and relationships of the data.

# %% [markdown]
# ## Step 4: Create a Problem Statement.
#
# ##### Having explored the data, come up with a problem statement for this data set. You can feel free to introduce data from any other source to support your problem statement, just be sure to provide a link to the origin of the data. Once again- be creative!

# %% [markdown]
# ## Step 5: Brainstorm your Approach.
# ##### In bullet-list form, provide a proposed approach for evaluating your problem statement. This can be somewhat high-level, but start to think about ways you can massage the data for maximum efficacy.

# %% [markdown]
# ## Step 6: Create a blog post with your code snippets and visualizations.
# ##### Data Science is a growing field, and the Tech industry thrives off of collaboration and sharing of knowledge. Blogging is a powerful means for pushing the needle forward in our field. Using your blogging platform of choice, create a post describing each of the 5 steps above. Rather than writing a procedural text, imagine you're describing the data, visualizations, and conclusions you've arrived at to your peers. Aim for a minimum of 500 words.

# %% [markdown]
# ## BONUS: The Content Managers working for the Podcast Publishing Company have recognized you as a thought leader in your field. They've asked you to pen a white paper (minimum 500 words) on the subject of 'What It Means To Have Clean Data'. This will be an opinion piece read by a wide audience, so be sure to back up your statements with real world examples or scenarios.
#
# ##### Hint: To get started, look around on the internet for articles, blog posts, papers, youtube videos, podcasts, reddit discussions, anything that will help you understand the challenges and implications of dealing with big data. This should be a personal reflection on everything you've learned this week, and the learning goals that have been set out for you going forward.
