# %%
import wikipedia

# %%
print wikipedia.summary("Data Science")
# Out:
# Data science is an interdisciplinary field about processes and systems to extract knowledge or insights from data in various forms, either structured or unstructured, which is a continuation of some of the data analysis fields such as statistics, data mining, and predictive analytics, similar to Knowledge Discovery in Databases (KDD).

# %%
wikipedia.search("Data Science")
# Out:
# [u'Data science',
#  u'Committee on Data for Science and Technology',
#  u'Vertex (company)',
#  u'Drew Conway',
#  u'Berkeley Institute for Data Science',
#  u'Pivotal Software',
#  u'The Data Incubator',
#  u'Alan Turing Institute',
#  u'Data Science Institute',
#  u'Kaggle']

# %%
data_science = wikipedia.page("Data Science")
data_science
# Out:
# <WikipediaPage 'Data science'>

# %%
data_science.url
# Out:
# u'https://en.wikipedia.org/wiki/Data_science'

# %%
data_science.content
# Out:
# u'Data science is an interdisciplinary field about processes and systems to extract knowledge or insights from data in various forms, either structured or unstructured, which is a continuation of some of the data analysis fields such as statistics, data mining, and predictive analytics, similar to Knowledge Discovery in Databases (KDD).\n\n\n== Overview ==\nData science employs techniques and theories drawn from many fields within the broad areas of mathematics, statistics, operations research, information science, and computer science, including signal processing, probability models, machine learning, statistical learning, data mining, database, data engineering, pattern recognition and learning, visualization, predictive analytics, uncertainty modeling, data warehousing, data compression, computer programming, artificial intelligence, and high performance computing. Methods that scale to big data are of particular interest in data science, although the discipline is not generally c
# ...

# %%
data_science.links[0]
# Out:
# u'American Statistical Association'

# %%
wikipedia.set_lang("en")

# %%
wikipedia.summary("Data Science", sentences=1)
# Out:
# u'Data science is an interdisciplinary field about processes and systems to extract knowledge or insights from data in various forms, either structured or unstructured, which is a continuation of some of the data analysis fields such as statistics, data mining, and predictive analytics, similar to Knowledge Discovery in Databases (KDD).'

# %%
wikipedia.random(pages=25)
# Out:
# [u'Lecithocera querula',
#  u'Tail number',
#  u'Inachus',
#  u'Seven Years in Tibet (1956 film)',
#  u'2010 UEFA European Under-17 Championship elite round',
#  u'Upper Crust (restaurant chain)',
#  u'Penicillium lignorum',
#  u'The Grand Hotel, Hughenden',
#  u'Jan Baas',
#  u'Muckenthaler House',
#  u'XAM',
#  u'Power Racing Series',
#  u'Carabus marietti ormanensis',
#  u"Paul O'Neill (racing driver)",
#  u'Samuel Norrby',
#  u'Titanium Seal',
#  u'William H. McNichols Jr.',
#  u'AS B\xe9ziers (2007)',
#  u'Karst fenster',
#  u'Felix Aderca',
#  u'2012 ICC World Twenty20',
#  u'Shahrak Emam Khomeyni, Lorestan',
#  u'Tom Lonie',
#  u'B\u0142adnice',
#  u'Phebalium whitei']

# %%
marie_antoinette = wikipedia.page('Marie Antoinette')
marie_antoinette
# Out:
# <WikipediaPage 'Marie Antoinette'>

# %%
marie_antoinette.content
# Out:
# u'Marie Antoinette (/\u02c8m\xe6ri\u02cc\xe6ntw\u0259\u02c8n\u025bt/, /\u02cc\u0251\u0303\u02d0ntw\u0259-/, /\u02cc\u0251\u0303\u02d0tw\u0259-/, US /m\u0259\u02c8ri\u02d0-/; French: [ma\u0281i \u0251\u0303twan\u025bt]; born Maria Antonia Josepha Johanna von Habsburg-Lothringen (2 November 1755 \u2013 16 October 1793), an Archduchess of Austria, was the fifteenth and second youngest child of Francis I, Holy Roman Emperor and Empress Maria Theresa.\nIn April 1770, upon her marriage (at the age of 14 years and 5 months) to Louis-Auguste, heir to the throne of France, she became Dauphine of France. On 10 May 1774, when her husband ascended the throne as Louis XVI, upon the death of his grandfather Louis XV, she became Queen of France and Navarre, a title she held until September 1791, when, as the French Revolution proceeded, she became Queen of the French, a title she held until 21 September 1792.\nAfter eight years of marriage, Marie Antoinette gave birth to a daughter, Marie-Th\xe9r\x
# ...
